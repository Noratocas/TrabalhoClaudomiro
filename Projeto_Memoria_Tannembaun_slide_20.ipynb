# %% [markdown]
# <a href="https://colab.research.google.com/github/Noratocas/TrabalhoClaudomiro/blob/main/Projeto_Memoria_Tannembaun_slide_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Projeto Memoria Tannembaun slide 20

# %% [markdown]
# Docente: Claudomiro de Souza Sales Junior
#
# Discente: Lucas Santos Gomes da Paixão
#
# Curso: Inteligência Artificial
#
# Matrícula: 202692540005

# %% [markdown]
# Projete um sistema de memória que possui 16 linhas de dados (BD). Os pinos de endereço precisam ser menores que 14. A memória deve ter capacidade de 32 Gbits. Justifique cada decisão do projeto. Desenhe o chip. Qual é o tamanho do barramento de endereços?

# %% [markdown]
# Projeto:
#
# A capacidade da Memória é de 32Gbits ou 2³⁰.2⁵ = 2³⁵
#
# A capacidade de endereçamento é a relação da capacidade de memória por largura de barramento. Mas, neste caso a largura de barramento é o mesmo valor de linhas de dados(16): 2³⁵ / 2⁴ = 2³¹ ou 2Gbits.
#
# O valor em bits do barramento de dados é a mesma da quantidade das linhas de dados: 16 linhas, 16 bits ou 2⁴.
#
# O barramento de endereços é obrigatório que seja menor que 14. Então 13 pinos será utilizado, mas 13 linhas de endereçamento não satisfaz a capacidade de endereçamento que é de 2³¹. Então, será necessário usar RAS e CAS dobrando a quantidade para 26 bits, ainda não satisfaz a capacidade da memória. Então, para manter os 13 pinos será necessário adicionar bancos. Portanto, para chegar em 2³¹ é necessário ter 5 linhas bancos ou 2⁵ que é a quantidade de possibilidades, assim satisfazendo a capacidade de endereçamento.

# %% [markdown]
# ![memoria2.png](data:image/png;base64,...)
